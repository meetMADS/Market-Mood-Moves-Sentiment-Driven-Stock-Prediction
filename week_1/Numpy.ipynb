# %% [markdown]
# # WiDS 5.0 Market Mood & Moves - Week 1: NumPy Tutorial
#
# **Topic:** Numerical Computing with NumPy
#
# **Objective:** Efficiently handle large, multi-dimensional arrays and matrices for financial calculations.
#
# ## 1. Setup

# %%
import numpy as np

# %% [markdown]
# ## 2. Creating Arrays & Basic Stats
#
# NumPy arrays are faster and more memory-efficient than Python lists.

# %%
# A simple list of stock prices
prices_list = [100.5, 101.2, 99.8, 102.5, 103.0]

# Convert to NumPy array
prices_array = np.array(prices_list)

print("Array:", prices_array)
print("Type:", type(prices_array))
# Out:
# Array: [100.5 101.2  99.8 102.5 103. ]
# Type: <class 'numpy.ndarray'>

# %% [markdown]
# ### Statistical Measures
# Financial engineering relies heavily on mean (average) and standard deviation (volatility).

# %%
mean_price = np.mean(prices_array)
std_dev = np.std(prices_array)

print(f"Mean Price: {mean_price}")
print(f"Volatility (Std Dev): {std_dev}")
# Out:
# Mean Price: 101.4
# Volatility (Std Dev): 1.1983321743156201

# %% [markdown]
# ## 3. Element-wise Operations
#
# Unlike lists, you can do math on the whole array at once.

# %%
# Simulate a 5% market crash on all prices
crash_prices = prices_array * 0.95
print("Prices after 5% drop:", crash_prices)
# Out:
# Prices after 5% drop: [95.475 96.14  94.81  97.375 97.85 ]
